# %%
print("hi")
# Out:
# hi

# %%
n1=10
n2=20
add=n1+n2
print("the addition of {} and {} is {}".format(n1,n2,add))
# Out:
# the addition of 10 and 20 is 30

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))

# %%
addition()
# Out:
# the addition of 10 and 20 is 30

# %%
def add():
    n1=10
    n2=20
    add=n1+n2
    print("the add of {} and {} is {}".format(n1,n2,add))

# %%
add()
# Out:
# the add of 10 and 20 is 30

# %%
def addition():
    n1=eval(input("enter number"))
    print("hello")

# %%
addition()
# Out:
# enter number5
# hello

# %%
def hello_world():
    print ("hello good morning")

# %%
# Out:
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# hello good morning
# ...

# %%
def avg():
    n1=eval(input("enter number:"))
    n2=eval(input("enter number:"))
    n3=eval(input("enter number:"))
    avg=(n1+n2+n3)/3
    print("the average of {},{},and {} is {}".format(n1,n2,n3,avg))

# %%
avg()
# Out:
# enter number:10
# enter number:20
# enter number:30
# the average of {},{},and {} is {}.format(n1,n2,n3,avg)

# %%
def avg():
    n1=eval(input("enter number:"))
    n2=eval(input("enter number:"))
    n3=eval(input("enter number:"))
    avg=(n1+n2+n3)/3
    print("the average of {},{},and {} is {}".format(n1,n2,n3,avg))

# %%
avg()
# Out:
# enter number:10
# enter number:20
# enter number:40
# the average of 10,20,and 40 is 23.333333333333332

# %%
avg()
# Out:
# enter number:10
# enter number:20
# enter number:30
# the average of 10,20,and 30 is 20.0

# %%
def avg1():
    try:
        
        n1=eval(input("enter number:"))
        n2=eval(input("enter number:"))
        n3=eval(input("enter number:"))
        avg=(n1+n2+n3)/3
        print("the average of {},{},and {} is {}".format(n1,n2,n3,avg))
    except Exception as e:
        print(e)

# %%
avg1()
# Out:
# enter number:10
# enter number:20
# enter number:30
# the average of 10,20,and 30 is 20.0

# %%
def totalbill():
     a1=eval(input("enter bill:"))
     a2=eval(input("enter tip :"))
     addition(a1+a2)
     print("the addition of {},{} is {}.format (a1,a2,addition)")

# %%
addition()
# Out:
# enter number500
# hello

# %%
def totalbill():
     a1=eval(input("enter bill:"))
     a2=eval(input("enter tip :"))
     totalbill(a1+a2)
     print("add {},{} is {}".format (a1,a2,totalbill))

# %%
totalbill()
# Out:
# enter bill:10
# enter tip :20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 totalbill()
#
# Cell In[27], line 4, in totalbill()
#       2 a1=eval(input("enter bill:"))
#       3 a2=eval(input("enter tip :"))
# ----> 4 addition(a1+a2)
#       5 print("the addition of {},{} is {}.format (a1,a2,addition)")
#
# TypeError: addition() takes 0 positional arguments but 1 was given

# %%
def bill():
     a1=eval(input("enter bill:"))
     a2=eval(input("enter tip :"))
     totalbill=bill amt + tip amt
     print("add {},{} is {}".format (a1,a2,totalbill))

# %%
bill()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 bill()
#
# NameError: name 'bill' is not defined

# %%
totalbill()
# Out:
# enter bill:1
# enter tip :0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 totalbill()
#
# Cell In[34], line 4, in totalbill()
#       2 a1=eval(input("enter bill:"))
#       3 a2=eval(input("enter tip :"))
# ----> 4 totalbill(a1+a2)
#       5 print("add {},{} is {}".format (a1,a2,totalbill))
#
# TypeError: totalbill() takes 0 positional arguments but 1 was given

# %%
import random 
def even_odd():
    num=random.randint(1,1000)
    if num%2==0:
        print("{} is a even number")
    else:
        print("{} is odd number")

# %%
even_odd()
# Out:
# {} is odd number

# %%
def bill():
     a1=eval(input("enter bill amt:"))
     a2=eval(input("enter tip amt :"))
     totalbill=bill amt + tip amt
     print("add {},{} is {}".format (a1,a2,totalbill))
# Out:
#   Cell In[42], line 4
#     totalbill=bill amt + tip amt
#                    ^
# SyntaxError: invalid syntax

# %%
def bill():
     a1=eval(input("enter bill amt:"))
     a2=eval(input("enter tip amt :"))
     totalbill= bill amt + tip amt
     print("add {},{} is {}".format (a1,a2,totalbill))
# Out:
#   Cell In[44], line 4
#     totalbill= bill amt + tip amt
#                     ^
# SyntaxError: invalid syntax
